# %% [markdown]
# # Compile all event features used for linear regression here
#
# In this notebook, we import the data we have precomputed and add a few other features that seem useful. The precomputed features are:
# 1. A time best fit line based on physics literature: The specific features we have extracted are the velocity of this line (vx_t, vy_t, vz_t), the predicted angle based on this (az_t_pred, ze_t_pred), and the mae of this line (mae_t).
# 2. A PCA best fit line: The specific features we had extracted are the velocity of the line (vx_pca, vy_pca, vz_pca), the predicted angle based on this (az_pca_pred, ze_pca_pred)
# 3. The number of clusters corresponding to each event
#
# We normalize these data points so that all the azimuths are in [0, 2\pi] and all the zeniths are in [0, \pi]. Also, if the zenith is 0 or \pi, then the azimuth is automatically set to 0.
#
# We compute a few extra features in this notebook, namely:
# 1. The mse of the time best fit line (mse, mse_squared)
# 2. The dot product of the two best fit lines.
# 3. Make number of clusters a categorical variable
# 4. Find a cutoff mse that splits the data into two groups, one with "good" and one with "bad" mse and make this a categorical variable
# 5. For each event, compute which "side" of the detectors the points are located at (categorical variables for x,y, and z).
#
# We then save all this data to use in our linear regressions.

# %%
# Import packages 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math

# %%
# Time best fit line data to standardize
data_t = pd.read_csv("C:/Users/k_vsl/Documents/Erdos/Boot Camp/ice-cube-katja/best-fit-batch10.csv")
data_pca = pd.read_csv("C:/Users/k_vsl/Documents/Erdos/Boot Camp/ice-cube-katja/batch10_pca_directions_aux_false.csv")
data_clusters = pd.read_csv("C:/Users/k_vsl/Documents/Erdos/Boot Camp/ice-cube-katja/batch10_aux_false_clusters.csv")
mses = pd.read_csv("C:/Users/k_vsl/Documents/Erdos/Boot Camp/ice-cube-katja/mse.csv")

# %%
event_ids = np.unique(data_t.event_id.values)

# %%
fixed_data = pd.DataFrame(index = event_ids, columns = ["event_id", "vx_t", "vy_t", "vz_t", "az_t_pred", "ze_t_pred", "mae_t", "mse_squared", "mse", "vx_pca", "vy_pca", "vz_pca", "az_pca_pred", "ze_pca_pred", "az_true", "ze_true"])

# %% [markdown]
# # Normalize Angles/Velocities:
#
# Standardize the angles and velocities for each best fit line so velocities have norm 1 and the angles are az: [0, 2\pi] and ze: [0, \pi]. Also ensure that angles which are purely vertical have no horizontal angle.

# %%
# Function that normalizes zenith and azimuth 
def normalize(vx, vy, vz, az, ze): 
    mod2 = np.square(vx) + np.square(vy) + np.square(vz)
    if mod2 == 0:
        mod = 1
    else: 
        mod = np.sqrt(mod2)
    vx_n = vx/mod
    vy_n = vy/mod
    vz_n = vz/mod
    if vz_n >= 1: 
        ze = 0
        az = 0
    if vz_n <= -1: 
        ze = math.pi
        az = 0
    else: 
        if az < 0: 
            az = az + 2 * math.pi
        if ze < 0: 
            ze = ze + math.pi
    return (vx_n, vy_n, vz_n, az, ze)

# %%
# Standardize pca data
i = 0
for row in data_pca.itertuples(): 
    event_id = row.event_id
    vx = row.vx
    vy = row.vy
    vz = row.vz
    az = row.az
    ze = row.ze
    vx_pca, vy_pca, vz_pca, az_pca_pred, ze_pca_pred = normalize(vx,vy,vz, az, ze)
    fixed_data.loc[event_id]["vx_pca"] = vx_pca
    fixed_data.loc[event_id]["vy_pca"] = vy_pca
    fixed_data.loc[event_id]["vz_pca"] = vz_pca
    fixed_data.loc[event_id]["az_pca_pred"] = az_pca_pred
    fixed_data.loc[event_id]["ze_pca_pred"] = ze_pca_pred
    
    i += 1
    if i % 10000 == 0: 
        print("On index " + str(i))
# Out:
# On index 10000
# On index 20000
# On index 30000
# On index 40000
# On index 50000
# On index 60000
# On index 70000
# On index 80000
# On index 90000
# On index 100000
# On index 110000
# On index 120000
# On index 130000
# On index 140000
# On index 150000
# On index 160000
# On index 170000
# On index 180000
# On index 190000
# On index 200000

# %%
# Standardize time best fit data
i = 0
for row in data_t.itertuples():
    event_id = row.event_id
    vx = row.vx
    vy = row.vy
    vz = row.vz
    az = row.az_pred
    ze = row.ze_pred
    az_true = row.az_true
    ze_true = row.ze_true
    mae = row.mae
    vx_t, vy_t, vz_t, az_t_pred, ze_t_pred = normalize(vx, vy, vz, az, ze)
    az_true = az_true
    ze_true = ze_true
    mae_t = mae
    fixed_data.loc[event_id]["vx_t"] = vx_t
    fixed_data.loc[event_id]["vy_t"] = vy_t
    fixed_data.loc[event_id]["vz_t"] = vz_t
    fixed_data.loc[event_id]["az_t_pred"] = az_t_pred
    fixed_data.loc[event_id]["ze_t_pred"] = ze_t_pred
    fixed_data.loc[event_id]["az_true"] = az_true
    fixed_data.loc[event_id]["ze_true"] = ze_true
    fixed_data.loc[event_id]["mae_t"] = mae_t
    if i % 10000 == 0:
        print("The index is " + str(i))
    i += 1
# Out:
# The index is 0
# The index is 10000
# The index is 20000
# The index is 30000
# The index is 40000
# The index is 50000
# The index is 60000
# The index is 70000
# The index is 80000
# The index is 90000
# The index is 100000
# The index is 110000
# The index is 120000
# The index is 130000
# The index is 140000
# The index is 150000
# The index is 160000
# The index is 170000
# The index is 180000
# The index is 190000

# %% [markdown]
# # Clustering

# %%
# Add number of clusters
fixed_data['num_clusters'] = data_clusters.num_clusters.values

# %%
fixed_data.head()
# Out:
#          event_id      vx_t      vy_t      vz_t az_t_pred ze_t_pred     mae_t  \
# 29296372      NaN  0.840768  0.133669  0.524635  0.157664   1.01851  2.595228
# 29296374      NaN  0.211115 -0.119066  0.970182  5.769669  0.244814  0.045669
# 29296414      NaN -0.368366  -0.91147 -0.183109  4.328315  1.754944   1.12855
# 29296416      NaN  0.539816 -0.666199  0.514566  5.393375  1.030295  2.349623
# 29296437      NaN   0.10565 -0.889777  0.443999  4.830573   1.11074  0.635174
#
#          mse_squared  mse    vx_pca    vy_pca    vz_pca az_pca_pred  \
# 29296372         NaN  NaN  0.950603  0.151131  0.271134    0.157664
# 29296374         NaN  NaN  0.195457 -0.145903  0.969798    5.641945
# 29296414         NaN  NaN -0.358119 -0.886117 -0.294191    4.328315
# 29296416         NaN  NaN  0.629551 -0.776942  0.005176    5.393375
# 29296437         NaN  NaN  0.007387 -0.906071  0.423061    4.720542
#
#          ze_pca_pred   az_true   ze_true  num_clusters
# 29296372    1.296226  3.517532  1.616892           1.0
# 29296374    0.246393  5.775634  0.199164           4.0
# 29296414    1.869405  3.715111  0.769641           1.0
# 29296416    1.565621  2.613874  1.399564           1.0
# 29296437    1.133976  4.110431  1.054067           2.0

# %% [markdown]
# # Dot Product

# %%
# Get dot product of v_t and v_pca for each entry
dot_product = np.zeros(len(event_ids))
i = 0
for row in fixed_data.itertuples():
    vx_t = row.vx_t
    vy_t = row.vy_t
    vz_t = row.vz_t
    vx_pca = row.vx_pca
    vy_pca = row.vy_pca
    vz_pca = row.vz_pca
    dot = np.dot((vx_t, vy_t, vz_t), (vx_pca, vy_pca, vz_pca))
    dot_product[i] = np.abs(dot)
    i = i + 1

# %%
print("The min of the dot product is " + str(dot_product.min()))
print("The max of the dot product is " + str(dot_product.max()))
print("The mean of the dot product is " + str(dot_product.mean()))
# Out:
# The min of the dot product is 3.399761412093555e-05
# The max of the dot product is 1.0
# The mean of the dot product is 0.9395973408285097

# %%
fixed_data['dot_product'] = dot_product

# %% [markdown]
# # MSE and MSE Squared

# %%
mses.columns
# Out:
# Index(['Unnamed: 0', 'mse', 'not_squared'], dtype='object')

# %%
# Add mse values for each event, filling columns "mse_squared", "mse"
mse_squared = mses.mse.values
mse = mses.not_squared.values
fixed_data["mse_squared"] = mse_squared
fixed_data["mse"] = mse

# %%
fixed_data.head(20)
# Out:
#          event_id      vx_t      vy_t      vz_t az_t_pred ze_t_pred     mae_t  \
# 29296372      NaN  0.840768  0.133669  0.524635  0.157664   1.01851  2.595228
# 29296374      NaN  0.211115 -0.119066  0.970182  5.769669  0.244814  0.045669
# 29296414      NaN -0.368366  -0.91147 -0.183109  4.328315  1.754944   1.12855
# 29296416      NaN  0.539816 -0.666199  0.514566  5.393375  1.030295  2.349623
# 29296437      NaN   0.10565 -0.889777  0.443999  4.830573   1.11074  0.635174
# 29296449      NaN -0.082325  0.517377  0.851788  1.728593  0.551407  1.928713
# 29296484      NaN -0.726709  0.370045 -0.578758  2.670607  2.188002  0.110184
# 29296493      NaN       0.0      -0.0      -1.0         0  3.141593  1.740515
# 29296496      NaN  0.403821  0.285576  0.869123  0.615532   0.51737  0.065858
# 29296505      NaN  0.184698  0.479771  0.857733  1.203312  0.539952  0.431063
# 29296523      NaN -0.572395  0.193769  0.796754  2.815179  0.648891  1.750756
# 29296537      NaN  0.233814 -0.328766   0.91501  5.330583  0.415263  1.691457
# 29296539      NaN  0.509843 -0.629317  0.586532   5.39329  0.944025  2.226874
# 29296546      NaN -0.364294 -0.058382  0.929452  3.300503  0.377871   0.81805
# 29296600      NaN -0.362975 -0.929705  0.062432  4.340169  1.508324   0.44161
# 29296609      NaN       0.0       0.0       1.0         0         0  0.604487
# 29296623      NaN  0.252159  0.677619  0.690832  1.214549  0.808157  2.058796
# 29296647      NaN      -0.0      -0.0      -1.0         0  3.141593  0.420435
# 29296653      NaN  0.112054  0.650181 -0.751471  1.400131  2.421085  0.662213
# 29296717      NaN  0.314302  0.049412  0.948036  0.155934  0.323791  0.124982
#
#            mse_squared          mse    vx_pca    vy_pca    vz_pca az_pca_pred  \
# 29296372  2.322060e+05   481.877540  0.950603  0.151131  0.271134    0.157664
# 29296374  1.174334e+06  1083.666960  0.195457 -0.145903  0.969798    5.641945
# 29296414  1.552522e+04   124.600239 -0.358119 -0.886117 -0.294191    4.328315
# 29296416  4.948033e+05   703.422549  0.629551 -0.776942  0.005176    5.393375
# 29296437  4.716322e+06  2171.709365  0.007387 -0.906071  0.423061    4.720542
# 29296449  1.009317e+06  1004.647895 -0.083098  0.522234  0.848744    1.728593
# 29296484  3.877941e+05   622.731152  -0.79526  0.316625 -0.517021    2.762691
# 29296493  2.431108e+05   493.062638       0.0       0.0      -1.0           0
# 29296496  5.390553e+06  2321.756510   0.40626  0.296204  0.864416     0.62999
# 29296505  2.593434e+06  1610.414243  0.182321  0.473594  0.861666    1.203312
# 29296523  9.705298e+05   985.154718 -0.571295   0.19774  0.796568    2.808373
# 29296537  2.017790e+05   449.198229  0.107605 -0.150832  0.982686     5.33206
# 29296539  1.900013e+04   137.840969 -0.627909  0.774815  0.073433    2.251846
# 29296546  5.410439e+05   735.556873 -0.357845 -0.057505  0.932009    3.300928
# 29296600  2.507652e+04   158.355664   0.34645   0.88738  0.304186    1.198577
# 29296609  1.908312e+06  1381.416577      -0.0       0.0       1.0           0
# 29296623  7.989449e+05   893.837201  0.261555  0.686702  0.678255    1.206875
# 29296647  6.751778e+05   821.692009       0.0       0.0      -1.0           0
# 29296653  3.554863e+05   596.226688  0.053721  0.637474 -0.768597    1.486723
# 29296717  8.251450e+05   908.374908  0.311749  0.049013    0.9489    0.155944
#
#          ze_pca_pred   az_true   ze_true  num_clusters  dot_product
# 29296372    1.296226  3.517532  1.616892           1.0     0.961684
# 29296374    0.246393  5.775634  0.199164           4.0     0.999517
# 29296414    1.869405  3.715111  0.769641           1.0     0.993457
# 29296416    1.565621  2.613874  1.399564           1.0     0.860102
# 29296437    1.133976  4.110431  1.054067           2.0     0.994820
# 29296449    0.557191  4.037991  1.567998           2.0     0.999983
# 29296484    2.114163  2.798409  2.155779           2.0     0.994318
# 29296493    3.141593  4.653443  1.401078           1.0     1.000000
# 29296496    0.526808  0.590728  0.452531           3.0     0.999929
# 29296505    0.532254   0.26674  0.280125           2.0     0.999970
# 29296523    0.649199  2.168351  2.308457           5.0     0.999991
# 29296537    0.186358  1.892104  1.293311           1.0     0.973915
# 29296539    1.497297  1.100555  2.193036           1.0     0.764668
# 29296546     0.37088  2.387041  1.012383           3.0     0.999976
# 29296600    1.261712  4.453681   1.93568           1.0     0.931763
# 29296609           0  4.630276  0.604487           1.0     1.000000
# 29296623    0.825412  4.737856  1.308457           2.0     0.999836
# 29296647    3.141593  5.264949  2.721157           1.0     1.000000
# 29296653    2.447441  2.518218  2.976789           3.0     0.998071
# 29296717    0.321066  6.115146   0.38113           3.0     0.999996

# %%
fixed_data["event_id"] = fixed_data.index

# %%
fixed_data.reset_index(drop = True)
# Out:
#         event_id      vx_t      vy_t      vz_t az_t_pred ze_t_pred     mae_t  \
# 0       29296372  0.840768  0.133669  0.524635  0.157664   1.01851  2.595228
# 1       29296374  0.211115 -0.119066  0.970182  5.769669  0.244814  0.045669
# 2       29296414 -0.368366  -0.91147 -0.183109  4.328315  1.754944   1.12855
# 3       29296416  0.539816 -0.666199  0.514566  5.393375  1.030295  2.349623
# 4       29296437   0.10565 -0.889777  0.443999  4.830573   1.11074  0.635174
# ...          ...       ...       ...       ...       ...       ...       ...
# 199995  32567581  0.906319  0.244411  0.344746  0.263408  1.218828  0.139888
# 199996  32567639  0.694877  0.278872 -0.662855  0.381649  2.295422  2.898224
# 199997  32567659  -0.17537  0.212403  0.961317  2.260982  0.279052  2.414195
# 199998  32567680  0.535383  0.550844 -0.640263  0.799631  2.265636   0.14919
# 199999  32567683  0.054476 -0.780513  0.622762  4.782072  0.898529  1.452211
#
#          mse_squared          mse    vx_pca    vy_pca    vz_pca az_pca_pred  \
# 0       2.322060e+05   481.877540  0.950603  0.151131  0.271134    0.157664
# 1       1.174334e+06  1083.666960  0.195457 -0.145903  0.969798    5.641945
# 2       1.552522e+04   124.600239 -0.358119 -0.886117 -0.294191    4.328315
# 3       4.948033e+05   703.422549  0.629551 -0.776942  0.005176    5.393375
# 4       4.716322e+06  2171.709365  0.007387 -0.906071  0.423061    4.720542
# ...              ...          ...       ...       ...       ...         ...
# 199995  7.603994e+05   872.008808  0.910331  0.248632  0.330878     0.26662
# 199996  7.919173e+05   889.897365  0.683626  0.264641 -0.680162    0.369348
# 199997  2.484241e+06  1576.147445 -0.182435  0.220959  0.958068    2.260982
# 199998  1.210059e+04   110.002675  0.406316  0.801088 -0.439506    1.101401
# 199999  3.838175e+06  1959.126173  0.064021 -0.782967   0.61876    4.793975
#
#        ze_pca_pred   az_true   ze_true  num_clusters  dot_product
# 0         1.296226  3.517532  1.616892           1.0     0.961684
# 1         0.246393  5.775634  0.199164           4.0     0.999517
# 2         1.869405  3.715111  0.769641           1.0     0.993457
# 3         1.565621  2.613874  1.399564           1.0     0.860102
# 4         1.133976  4.110431  1.054067           2.0     0.994820
# ...            ...       ...       ...           ...          ...
# 199995    1.233562  0.353034  1.329428           2.0     0.999887
# 199996     2.31878  3.437011  1.079144           2.0     0.999686
# 199997    0.290614  1.112257  2.569093           2.0     0.999933
# 199998    2.025845  0.898184  2.139322           1.0     0.940208
# 199999    0.903633   3.66867  1.910443           4.0     0.999943
#
# [200000 rows x 18 columns]

# %%
data_to_csv = fixed_data.to_csv('all-feature.csv', index = True)

# %% [markdown]
# # Investigate cutoffs for MSE and dot product

# %%
# Code to figure out best cutoff for mse
cutoffs = np.arange(720,740, 1)
n = len(cutoffs)
bad_mse = np.zeros(n)
good_mse = np.zeros(n)
for i in range(0,n): 
    cutoff = cutoffs[i]
    X_bad_mse = fixed_data[fixed_data.mse > cutoff]
    X_good_mse = fixed_data[fixed_data.mse < cutoff]
    bad_mse[i] = X_bad_mse.mae_t.values.mean()
    good_mse[i] = X_good_mse.mae_t.values.mean()

# %%
# Graph for different cutoffs
plt.figure(figsize=(8,6))

plt.scatter(cutoffs,
               bad_mse, 
           c = 'orange')
plt.scatter(cutoffs,
               good_mse, 
           c = 'blue')

plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

plt.show()

# %% [markdown]
# Result: Cutoff of 721 makes most sense as it minimizes mae in the "bad" group

# %%
# Get categorical variable for mse
i = 0
mse_cat = np.zeros(len(fixed_data))
for row in fixed_data.itertuples(): 
    mse = row.mse
    if mse <= 721:
        mse_cat[i] = np.uint8(0)
    else:
        mse_cat[i] = np.uint8(1)
    i += 1
fixed_data['mse_cat'] = mse_cat

# %%
# Code to figure out dot_product cutoffs
cutoffs = np.arange(0,1, .01)
n = len(cutoffs)
bad_dot = np.zeros(n)
good_dot = np.zeros(n)
for i in range(0,n): 
    cutoff = cutoffs[i]
    X_bad_dot = fixed_data[fixed_data.dot_product > cutoff]
    X_good_dot = fixed_data[fixed_data.dot_product < cutoff]
    bad_mse[i] = X_bad_dot.mae_t.values.mean()
    good_mse[i] = X_good_dot.mae_t.values.mean()

# %%
# Graph for different cutoffs
plt.figure(figsize=(8,6))

plt.scatter(cutoffs,
               bad_dot, 
           c = 'orange')
plt.scatter(cutoffs,
               good_dot, 
           c = 'blue')

plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

plt.show()

# %% [markdown]
# Result: MSE appeared to give better cutoffs

# %% [markdown]
# # Clusters as Categorical Variable

# %%
# Get categorical variable for num_clusters
fixed_data = fixed_data.set_index("event_id")
W = pd.get_dummies(fixed_data['num_clusters'], prefix = 'cat')
W['event_id'] = fixed_data.index.values
W = W.set_index("event_id")
data = pd.merge(fixed_data, W, left_index = True, right_index = True)

# %%
data.head()
# Out:
#           event_id_x      vx_t      vy_t      vz_t az_t_pred ze_t_pred  \
# 29296372    29296372  0.840768  0.133669  0.524635  0.157664   1.01851
# 29296374    29296374  0.211115 -0.119066  0.970182  5.769669  0.244814
# 29296414    29296414 -0.368366  -0.91147 -0.183109  4.328315  1.754944
# 29296416    29296416  0.539816 -0.666199  0.514566  5.393375  1.030295
# 29296437    29296437   0.10565 -0.889777  0.443999  4.830573   1.11074
#
#              mae_t   mse_squared          mse    vx_pca  ... cat_3.0 cat_4.0  \
# 29296372  2.595228  2.322060e+05   481.877540  0.950603  ...       0       0
# 29296374  0.045669  1.174334e+06  1083.666960  0.195457  ...       0       1
# 29296414   1.12855  1.552522e+04   124.600239 -0.358119  ...       0       0
# 29296416  2.349623  4.948033e+05   703.422549  0.629551  ...       0       0
# 29296437  0.635174  4.716322e+06  2171.709365  0.007387  ...       0       0
#
#          cat_5.0 cat_6.0 cat_7.0 cat_8.0  cat_9.0  cat_10.0  cat_11.0  \
# 29296372       0       0       0       0        0         0         0
# 29296374       0       0       0       0        0         0         0
# 29296414       0       0       0       0        0         0         0
# 29296416       0       0       0       0        0         0         0
# 29296437       0       0       0       0        0         0         0
#
#           event_id_y
# 29296372    29296372
# 29296374    29296374
# 29296414    29296414
# 29296416    29296416
# 29296437    29296437
#
# [5 rows x 31 columns]

# %% [markdown]
# # Determine where in ICE Cube the data points lean
#
# This feature is an effort to determine which side of the cone, the detections are coming from (If the detections are happening on one side of the detector, then potentially only one side of the cone would even be within the detector).

# %% [markdown]
# # Find where the data points are skewing and make categorical variables
# For each direction, determine which sign over 50% of the points lie in

# %%
# Function that given an event returns which quadrants the data is skewed to
def find_quad_event(event, geometry): 
    stats = event.reset_index()
    n = len(event)
    
    id_x = 0
    id_y = 0
    id_z = 0
    for i in range(0,n):
        id = stats.loc[i, "sensor_id"]
        x = geometry.iloc[id].x
        y = geometry.iloc[id].y
        z = geometry.iloc[id].z
        
        # Keep counts on positive coordinates
        if x > 0: 
            id_x += 1
        else: 
            id_x = id_x
            
        if y > 0: 
            id_y += 1
        else: 
            id_y = id_y
            
        if z > 0: 
            id_z += 1
        else: 
            id_z = id_z        
        i += 1
        
    per_x = id_x / n
    per_y = id_y / n
    per_z = id_z / n
    
    cat_x = 0
    cat_y = 0
    cat_z = 0
    
    if per_x > .5: 
        cat_x = 1
    if per_y > .5:
        cat_y = 1
    if per_z > .5: 
        cat_z = 1
        
    return (per_x, per_y, per_z, cat_x, cat_y, cat_z)

# %%
# Separate into quadrants (If most detections have (x > 0), (y > 0), (z > 0))

# load batch10
batch10 = pd.read_parquet("C:/Users/k_vsl/Documents/Erdos/IceCubeData/batch_10.parquet")
sensors = pd.read_csv("C:/Users/k_vsl/Documents/Erdos/IceCubeData/sensor_geometry.csv")

# Fo

def find_quad(aux_incl, batch, geometry):
    if aux_incl == False: 
        batch_aux = batch[batch.auxiliary==False]
    else: 
        batch_aux = batch
    event_ids = np.unique(data_t.event_id.values)
    n = len(event_ids)
    print(n)
    
    df = pd.DataFrame(index = event_ids, columns = ['per_x', 'per_y', 'per_z', 'cat_x', 'cat_y', 'cat_z'])
    
    
    # Loop through the events and populate the data frame
    for i in range(0, n): 
        event_id = event_ids[i]
        event = batch_aux.loc[event_id]
        stats = find_quad_event(event, geometry)
        
        df.loc[event_id, "per_x"] = stats[0]
        df.loc[event_id, "per_y"] = stats[1]
        df.loc[event_id, "per_z"] = stats[2]
        df.loc[event_id, "cat_x"] = stats[3]
        df.loc[event_id, "cat_y"] = stats[4]
        df.loc[event_id, "cat_z"] = stats[5]
        if (i % 1000 == 0): 
            print("Testing complete for " + str(i) + " events")
            
    return df

# %%
df = find_quad(False, batch10, sensors)
# Out:
# 200000
# Testing complete for 0 events
# Testing complete for 1000 events
# Testing complete for 2000 events
# Testing complete for 3000 events
# Testing complete for 4000 events
# Testing complete for 5000 events
# Testing complete for 6000 events
# Testing complete for 7000 events
# Testing complete for 8000 events
# Testing complete for 9000 events
# Testing complete for 10000 events
# Testing complete for 11000 events
# Testing complete for 12000 events
# Testing complete for 13000 events
# Testing complete for 14000 events
# Testing complete for 15000 events
# Testing complete for 16000 events
# Testing complete for 17000 events
# Testing complete for 18000 events
# Testing complete for 19000 events
# Testing complete for 20000 events
# Testing complete for 21000 events
# Testing complete for 22000 events
# Testing complete for 23000 events
# Testing complete for 24000 events
# Testing complete for 25000 events
# Testing complete for 26000 events
# Testing complete for 27000 events
# Testing complete for 28000 events
# Testing complete for 29000 events
# Testing complete for 30000 events
# Testing complete for 31000 events
# Testing complete for 32000 events
# Testing complete for 33000 events
# Testing complete for 34000 events
# Testing complete for 35000 events
# Testing complete for 36000 events
# Testing complete for 37000 events
# Testing complete for 38000 events
# Testing complete for 39000 events
# Testing complete for 40000 events
# Testing complete for 41000 events
# Testing complete for 42000 events
# Testing complete for 43000 events
# Testing complete for 44000 events
# Testing complete for 45000 events
# Testing complete for 46000 events
# Testing complete for 47000 events
# Testing complete for 48000 events
# Testing complete for 49000 events
# Testing complete for 50000 events
# Testing complete for 51000 events
# Testing complete for 52000 events
# Testing complete for 53000 events
# Testing complete for 54000 events
# Testing complete for 55000 events
# Testing complete for 56000 events
# Testing complete for 57000 events
# Testing complete for 58000 events
# Testing complete for 59000 events
# Testing complete for 60000 events
# Testing complete for 61000 events
# Testing complete for 62000 events
# Testing complete for 63000 events
# Testing complete for 64000 events
# Testing complete for 65000 events
# Testing complete for 66000 events
# Testing complete for 67000 events
# Testing complete for 68000 events
# Testing complete for 69000 events
# Testing complete for 70000 events
# Testing complete for 71000 events
# Testing complete for 72000 events
# Testing complete for 73000 events
# Testing complete for 74000 events
# Testing complete for 75000 events
# Testing complete for 76000 events
# Testing complete for 77000 events
# Testing complete for 78000 events
# Testing complete for 79000 events
# Testing complete for 80000 events
# Testing complete for 81000 events
# Testing complete for 82000 events
# Testing complete for 83000 events
# Testing complete for 84000 events
# Testing complete for 85000 events
# Testing complete for 86000 events
# Testing complete for 87000 events
# Testing complete for 88000 events
# Testing complete for 89000 events
# Testing complete for 90000 events
# Testing complete for 91000 events
# Testing complete for 92000 events
# Testing complete for 93000 events
# Testing complete for 94000 events
# Testing complete for 95000 events
# Testing complete for 96000 events
# Testing complete for 97000 events
# Testing complete for 98000 events
# Testing complete for 99000 events
# Testing complete for 100000 events
# Testing complete for 101000 events
# Testing complete for 102000 events
# Testing complete for 103000 events
# Testing complete for 104000 events
# Testing complete for 105000 events
# Testing complete for 106000 events
# Testing complete for 107000 events
# Testing complete for 108000 events
# Testing complete for 109000 events
# Testing complete for 110000 events
# Testing complete for 111000 events
# Testing complete for 112000 events
# Testing complete for 113000 events
# Testing complete for 114000 events
# Testing complete for 115000 events
# Testing complete for 116000 events
# Testing complete for 117000 events
# Testing complete for 118000 events
# Testing complete for 119000 events
# Testing complete for 120000 events
# Testing complete for 121000 events
# Testing complete for 122000 events
# Testing complete for 123000 events
# Testing complete for 124000 events
# Testing complete for 125000 events
# Testing complete for 126000 events
# Testing complete for 127000 events
# Testing complete for 128000 events
# Testing complete for 129000 events
# Testing complete for 130000 events
# Testing complete for 131000 events
# Testing complete for 132000 events
# Testing complete for 133000 events
# Testing complete for 134000 events
# Testing complete for 135000 events
# Testing complete for 136000 events
# Testing complete for 137000 events
# Testing complete for 138000 events
# Testing complete for 139000 events
# Testing complete for 140000 events
# Testing complete for 141000 events
# Testing complete for 142000 events
# Testing complete for 143000 events
# Testing complete for 144000 events
# Testing complete for 145000 events
# Testing complete for 146000 events
# Testing complete for 147000 events
# Testing complete for 148000 events
# Testing complete for 149000 events
# Testing complete for 150000 events
# Testing complete for 151000 events
# Testing complete for 152000 events
# Testing complete for 153000 events
# Testing complete for 154000 events
# Testing complete for 155000 events
# Testing complete for 156000 events
# Testing complete for 157000 events
# Testing complete for 158000 events
# Testing complete for 159000 events
# Testing complete for 160000 events
# Testing complete for 161000 events
# Testing complete for 162000 events
# Testing complete for 163000 events
# Testing complete for 164000 events
# Testing complete for 165000 events
# Testing complete for 166000 events
# Testing complete for 167000 events
# Testing complete for 168000 events
# Testing complete for 169000 events
# Testing complete for 170000 events
# Testing complete for 171000 events
# Testing complete for 172000 events
# Testing complete for 173000 events
# Testing complete for 174000 events
# Testing complete for 175000 events
# Testing complete for 176000 events
# Testing complete for 177000 events
# Testing complete for 178000 events
# Testing complete for 179000 events
# Testing complete for 180000 events
# Testing complete for 181000 events
# Testing complete for 182000 events
# Testing complete for 183000 events
# Testing complete for 184000 events
# Testing complete for 185000 events
# Testing complete for 186000 events
# Testing complete for 187000 events
# Testing complete for 188000 events
# Testing complete for 189000 events
# Testing complete for 190000 events
# Testing complete for 191000 events
# Testing complete for 192000 events
# Testing complete for 193000 events
# Testing complete for 194000 events
# Testing complete for 195000 events
# Testing complete for 196000 events
# Testing complete for 197000 events
# Testing complete for 198000 events
# Testing complete for 199000 events

# %%
final = pd.merge(data, df, left_index = True, right_index = True)

# %%
final_to_csv = final.to_csv('features-final.csv', index = True)
